# %%
from choice_learn.datasets import load_expedia
from sklearn.model_selection import train_test_split

# %%
df = load_expedia(as_frame=True, preprocessing="rumnet")

# %%
target = "booking_bool"

X = df.drop(columns=target).to_numpy()
y = df[target].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)

# %%
X_train
# Out:
# array([[120, Timestamp('2013-01-06 10:22:49'), 5, ..., 24.0, 1, 185.96],
#        [240, Timestamp('2012-12-02 20:56:30'), 5, ..., nan, 0, nan],
#        [157, Timestamp('2013-04-23 02:51:56'), 5, ..., nan, 0, nan],
#        ...,
#        [97, Timestamp('2012-11-19 07:33:00'), 5, ..., 11.0, 1, 326.95],
#        [176, Timestamp('2013-04-28 12:25:18'), 25, ..., nan, 0, nan],
#        [85, Timestamp('2013-02-28 06:33:47'), 14, ..., nan, 0, nan]],
#       dtype=object)
